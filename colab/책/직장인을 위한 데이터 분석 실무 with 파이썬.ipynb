# %% [markdown]
# https://github.com/Play-with-data/datasalon

# %% [markdown]
# # 파일 다운로드

# %%
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/sample/sample.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/sample/sample_1.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/sample/sample_2.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/sample/sample_codemaster.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/sample/sample_index_false.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/다나와/1_danawa_crawling_result.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/다나와/2_danawa_data_final.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/스타벅스/daegu_starbucks_list.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/스타벅스/report.txt
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/스타벅스/report2.txt
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/스타벅스/seoul_sgg.geojson
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/스타벅스/seoul_sgg_list.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/스타벅스/seoul_sgg_stat.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/스타벅스/seoul_starbucks_list.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/스타벅스/sgg_biz.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/스타벅스/sgg_pop.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/외국인출입/kto_202210.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/외국인출입/kto_total.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/인스타/1_crawling_raw.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/인스타/3_location_counts.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/인스타/3_location_inform.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/인스타/3_locations.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/추출(지니%20벅스%20멜론%20유튜브)/bugs.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/추출(지니%20벅스%20멜론%20유튜브)/genie.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/추출(지니%20벅스%20멜론%20유튜브)/melon.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/추출(지니%20벅스%20멜론%20유튜브)/total.xlsx
# !wget https://github.com/leetae04kr/file_to_use/blob/main/직장인을%20위한%20데이터%20분석%20실무%20with%20파이썬%20사용파일/추출(지니%20벅스%20멜론%20유튜브)/youtube_rank.xlsx
# Out:
# --2022-12-14 01:03:30--  https://github.com/leetae04kr/file_to_use/blob/main/%EC%A7%81%EC%9E%A5%EC%9D%B8%EC%9D%84%20%EC%9C%84%ED%95%9C%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%20%EC%8B%A4%EB%AC%B4%20with%20%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%82%AC%EC%9A%A9%ED%8C%8C%EC%9D%BC/sample/sample.xlsx
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sample.xlsx.2’
#
# sample.xlsx.2           [ <=>                ] 145.67K  --.-KB/s    in 0.03s
#
# 2022-12-14 01:03:30 (5.61 MB/s) - ‘sample.xlsx.2’ saved [149170]
#
# ...

# %% [markdown]
# # 맷플로이립 폰트설정

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# ...

# %% [markdown]
# #웹 드라이버 설정

# %%
#이 부분은 처음 한번만 실행하면 됌.
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# ...

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')        # Head-less 설정
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome('chromedriver', options=options)

# %% [markdown]
# # pandas 맛보기

# %%
file_sample_1="./sample_1.xlsx"
file_sample_2="./sample_2.xlsx"
file_sample_codemaster="./sample_codemaster.xlsx"
file_sample="./sample.xlsx"
file_sample_index_false="./sample_index_false.xlsx"

# %% [markdown]
# ## 데이터 불러오기 (pd.read_excel)

# %%
# s 라이브러리 불러오기
import pandas as pd

# %%
# 엑셀데이터 불러오기
sample_1 = pd.read_excel(file_sample_1, 
                         header=1, 
                         skipfooter=2, 
                         usecols='A:C')
sample_1.head(3)

# %%
#  함수 활용
sample_1.tail(3)

# %%
# 데이터 정보 살펴보기 
sample_1.info()

# %%
#  데이터 기초통계량 확인 
sample_1.describe()

# %% [markdown]
# ##데이터 선택하기① - 컬럼(Column) 기준

# %%
# 데이터 확인하기 
sample_1

# %%
#  한 개 컬럼 선택하기 
sample_1['입국객수']

# %%
#여러 컬럼 선택하기 
sample_1[['국적코드', '입국객수']]

# %%
#  컬럼 생성하기 
sample_1['기준년월'] = '2019-11'
sample_1

# %% [markdown]
# ##데이터 선택하기② - 로우(Row) 기준

# %%
#  필터링하기 1
condition = (sample_1['성별'] == '남성')
condition

# %%
# 필터링하기 2
sample_1[condition]

# %%
# 필터링하기 3
condition = (sample_1['입국객수'] >= 150000) 
sample_1[condition]

# %%
#  데이터 확인하기 
sample_1

# %%
# 두 개 컬럼에 필터링하기 1
conditions = (sample_1['성별'] == '남성') & (sample_1['입국객수'] >= 150000)
conditions

# %%
#  두 개 컬럼에 필터링하기 2
sample_1[conditions]

# %%
# 두 개 컬럼에 필터링하기 3 - 가독성 좋게 표현하기 
conditions = (sample_1['성별'] == '남성') \
    & (sample_1['입국객수'] >= 150000)

sample_1[conditions]

# %%
#  한 컬럼에 여러 조건 필터링하기 1
conditions = (sample_1['국적코드'] == 'A01') \
                | (sample_1['국적코드'] == 'A18')
sample_1[conditions]

# %%
#  한 컬럼에 여러 조건 필터링하기 2 
conditions = (sample_1['국적코드'].isin(['A01', 'A18'])) 
conditions

# %%
#  한 컬럼에 여러 조건 필터링하기 3
sample_1[conditions]

# %%
#한 컬럼에 여러 조건 필터링하기 4
conditions = (sample_1['국적코드'].isin(['A01', 'A18'])) 
sample_1[conditions == False]

# %% [markdown]
# ##데이터 통합하기① - 옆으로 통합(pd.merge)

# %%
# 데이터 확인하기 
sample_1

# %%
# 국적코드표 엑셀파일 불러오기 
code_master = pd.read_excel(file_sample_codemaster)
code_master

# %%
# 데이터 옆으로 통합하기(left 조건) 
sample_1_code = pd.merge(left=sample_1, 
                         right=code_master,
                         how='left',
                         left_on='국적코드',
                         right_on='국적코드')
sample_1_code

# %%
#  데이터 옆으로 통합하기(inner 조건) 
sample_1_code_inner = pd.merge(left=sample_1, 
                               right=code_master,
                               how='inner',
                               left_on='국적코드',
                               right_on='국적코드')
sample_1_code_inner

# %% [markdown]
# 2.1.6. 데이터 통합하기② - 아래로 통합(pd.append)

# %%
#  sample_2_code 만들기
sample_2 = pd.read_excel(file_sample_2, 
                         header=1, 
                         skipfooter=2, 
                         usecols='A:C')
sample_2['기준년월']='2019-12'
sample_2_code = pd.merge(left=sample_2, 
                         right=code_master,
                         how='left',
                         left_on='국적코드',
                         right_on='국적코드')
sample_2_code

# %%
# sample_1_code 확인하기 
sample_1_code

# %%
#데이터 아래로 통합하기 1
sample = sample_1_code.append(sample_2_code, ignore_index=True)
sample

# %%
# 데이터 아래로 통합하기 2
sample_1_code.append(sample_2_code)

# %% [markdown]
# ## 데이터 집계하기(pivot_table)

# %%
# pivot_table() 함수 활용하기 1
sample_pivot = sample.pivot_table(values='입국객수',
                                  index='국적명',
                                  columns='기준년월',
                                  aggfunc='mean' )
sample_pivot

# %%
#  pivot_table() 함수 활용하기 2
sample_pivot_2 = sample.pivot_table(values='입국객수',
                                    index='국적명',
                                    aggfunc='max')
sample_pivot_2

# %% [markdown]
# # 웹크롤링 맛보기

# %% [markdown]
# ## selenium과 크롬드라이버 설치

# %%
#! pip install selenium
# selenium 라이브러리 불러오기
from selenium import webdriver

# %%
# 크롬드라이버 다운받기
# 크롬 다운로드 사이트 변경에 따른 주소 변경(updated 2022.10.01)
print('https://sites.google.com/chromium.org/driver/')

# %%
#이 부분은 처음 한번만 실행하면 됌.
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
#Colab에선 웹브라우저 창이 뜨지 않으므로 별도 설정한다.
 
options = webdriver.ChromeOptions()
options.add_argument('--headless')        # Head-less 설정
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome('chromedriver', options=options)

# %% [markdown]
# ## 웹 페이지 접속

# %%
# URL 접속하기
url = 'https://www.naver.com/'
driver.get(url)

# %% [markdown]
# ##웹 페이지(HTML) 다운로드

# %%
# 웹페이지 html 다운로드 하기
html = driver.page_source

# %% [markdown]
# ##BeautifulSoup을 이용한 정보 찾기

# %%
# 실습용 HTML
html = '''
<html>
    <head>
    </head>
    <body>
        <h1> 우리동네시장</h1>
            <div class = 'sale'>
                <p id='fruits1' class='fruits'>
                    <span class = 'name'> 바나나 </span>
                    <span class = 'price'> 3000원 </span>
                    <span class = 'inventory'> 500개 </span>
                    <span class = 'store'> 가나다상회 </span>
                    <a href = 'http://bit.ly/forPlaywithData' > 홈페이지 </a>
                </p>
            </div>
            <div class = 'prepare'>
                <p id='fruits2' class='fruits'>
                    <span class ='name'> 파인애플 </span>
                </p>
            </div>
    </body>
</html>
'''

# %%
#HTML 문자열 BeautifulSoup 으로 해석하기
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ##HTML 정보 찾기 ① - 태그 속성 활용

# %%
# 태그명으로 태그 찾기
tags_span = soup.select('span')
tags_p = soup.select('p')

# %%
# id와 class로 태그 찾기
ids_fruits1 = soup.select('#fruits1')
class_price = soup.select('.price')
tags_span_class_price = soup.select('span.price')

# %% [markdown]
# ## HTML 정보 찾기 ② - 상위 구조 활용

# %%
# 태그 구조로 위치 찾기①
tags_name = soup.select('span.name')
print(tags_name)

# %%
# 태그 구조로 위치 찾기②
tags_banana1 = soup.select('#fruits1 > span.name')
print(tags_banana1)

# %%
# 태그 구조로 위치 찾기③
tags_banana2 = soup.select('div.sale > #fruits1 > span.name')
tags_banana3 = soup.select('div.sale span.name')
print(tags_banana2)
print(tags_banana3)

# %% [markdown]
# ## 정보 가져오기 ① - 태그 그룹에서 하나의 태그 선택하기

# %%
#태그 그룹에서 하나의 태그만 선택하기
tags = soup.select('span.name')
tag_1 = tags[0]    #인덱스 번호로 하나의 태그 지정하기
print(tag_1)

# %%
#  태그 그룹에서 반복문으로 태그 하나씩 선택하기
tags = soup.select('span.name')
for tag in tags:      # 반복문으로 태그 그룹에서 각각의 태그 선택하여 활용하기
    print(tag)

# %% [markdown]
# ## 정보 가져오기 ② - 선택한 태그에서 정보 가져오기

# %%
# 선택한 태그에서 텍스트, 속성 값 가져오기
tags = soup.select('a')
tag = tags[0]
content = tag.text
print(content)
link = tag['href']
print(link)

# %% [markdown]
# ##멜론 노래 순위 정보 크롤링①

# %%
#  멜론 인기차트 웹페이지 접속하기
url = 'http://www.melon.com/chart/index.htm'
driver.get(url)

# %%
#HTML 다운로드 및 BeautifulSoup으로 읽기
from bs4 import BeautifulSoup
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
# 100개의 노래 태그 찾기  --> 사이트 개편으로 코드 변경됨(updated 2020.07.13)
songs = soup.select('tr')  
print(len(songs))
print(songs[0])

# %%
#  추가내용(updated 2020.07.13)
# 100개의 곡을 찾고 싶으나, 101개의 태그 뭉치가 검색됨    len(songs)  -->  101 
# 101개 중 첫 번째 태그 뭉치(songs[0]) 을 살펴보니 표에서 컬럼제목(곡정보/앨범/좋아요... )을 나타내고 있음
# 101개 중 첫 번째는 컬럼 제목,   두 번째 부터 끝까지,  남은 100개는 노래 정보 일 것으로 예상됨

songs = soup.select('tr')[1:]     # 첫 번째는 제외하고, 두 번째(인덱스번호 1) 부터 끝까지만 선택
print(len(songs))                 # 100  으로   정리하고 싶은 노래 개수에 맞게 선택됨
print(songs[0])                   # 그 중 첫 번째 태그를 보니, 1위 곡으로 조회됨

# %%
# 예제 2-55 한 개의 곡 정보 지정하기
song = songs[0]
print(song)   # 데이터 확인 할 경우 주석 해제하고 실행하세요

# %%
#  곡 제목 찾기 1
title = song.select('a')
len(title)

# %%
# 곡 제목 찾기 2
title = song.select('span > a')
len(title)

# %%
#  곡 제목 찾기 3
title = song.select('div.ellipsis.rank01 > span > a')
len(title)

# %%
# 곡 제목 가져오기
title = song.select('div.ellipsis.rank01 > span > a')[0].text
title

# %%
#  가수 찾기
singer = song.select('div.ellipsis.rank02 > a')
len(singer)

# %%
#  가수 정보 가져오기
singer = song.select('div.ellipsis.rank02 > a')[0].text
singer

# %%
# 멜론 50위 노래순위 정보 가져오기
for song in songs:                                        
    title = song.select('div.ellipsis.rank01 > span > a')[0].text
    singer = song.select ('div.ellipsis.rank02 > a')[0].text  
    print(title, singer, sep = ' | ')

# %%
# 멜론 인기차트 중 상위 50곡 크롤링(정리)  # 멜론 사이트 개편으로 코드 수정(updated 2020.07.13)
  
url = 'http://www.melon.com/chart/index.htm'
driver.get(url)          
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
                               
songs = soup.select('tr')[1:]     # 멜론 사이트 개편으로 코드 수정(updated 2020.07.13)
for song in songs:                                        
    title = song.select('div.ellipsis.rank01 > span > a')[0].text
    singer = song.select ('div.ellipsis.rank02 > a')[0].text  
    print(title, singer, sep = ' | ')

# %% [markdown]
# ##selenium을 활용한 크롤링

# %%
# 멜론 인기차트 중 상위 50곡 크롤링(selenium만 활용)
# selenium 명령어 변경으로 코드 수정(updated 2022.10.01)   (변경전) find_elements_by_css_selector →    (변경후) find_elements
from selenium import webdriver
url = 'http://www.melon.com/chart/index.htm'
driver.get(url)          
                                
songs = driver.find_elements( 'css selector', 'tr')[1:]     # 멜론 사이트 개편으로 코드 수정(updated 2020.07.13)
for song in songs:                                        
    title = song.find_elements( 'css selector', 'div.ellipsis.rank01 > span > a')[0].text
    singer = song.find_elements( 'css selector', 'div.ellipsis.rank02 > a')[0].text  
    print(title, singer, sep = ' | ')

# %% [markdown]
# # 멜론 크롤링 결과를 엑셀로 저장하기

# %%
#이 부분은 처음 한번만 실행하면 됌.
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin

# %%
#Colab에선 웹브라우저 창이 뜨지 않으므로 별도 설정한다.
 
options = webdriver.ChromeOptions()
options.add_argument('--headless')        # Head-less 설정
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome('chromedriver', options=options)

# %%
# 멜론 사이트 접속하기 
from selenium import webdriver
from bs4 import BeautifulSoup

url = 'http://www.melon.com/chart/index.htm'
driver.get(url)     

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
#  반복문을 이용해 곡과 가수명을 song_data에 저장하기 
song_data = []
rank = 1

songs = soup.select('table > tbody > tr')
for song in songs:                                        
    title = song.select('div.rank01 > span > a')[0].text
    singer = song.select('div.rank02 > a')[0].text
    song_data.append(['Melon', rank, title, singer])
    rank = rank + 1

# %%
# song_data 리스트를 이용해 데이터프레임 만들기 
import pandas as pd
columns = ['서비스', '순위', '타이틀', '가수']
pd_data = pd.DataFrame(song_data, columns = columns)
pd_data.head()

# %%
# 예제 3-4 크롤링 결과를 엑셀파일로 저장하기 
pd_data.to_excel('./melon.xlsx', index=False)

# %% [markdown]
# # 벅스 크롤링 결과를 엑셀 파일로 저장하기

# %%
# 벅스 사이트 접속하기 
from selenium import webdriver
from bs4 import BeautifulSoup


url  = 'https://music.bugs.co.kr/chart'
driver.get(url)     

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
#tr 태그로 곡 정보 찾기 1
songs = soup.select('tr')
print(len(songs))

# %%
# tr 태그로 곡 정보 찾기 2
songs = soup.select('tbody > tr')
print(len(songs))

# %%
#tr 태그로 곡 정보 찾기 3
songs = soup.select('table > tbody > tr')
print(len(songs))

# %%
# tr 태그로 곡 정보 찾기 4
songs = soup.select('table.byChart > tbody > tr')
print(len(songs))

# %%
# songs 태그 중 첫 번째 태그 출력해보기
print(songs[0])

# %%
#  한 개의 곡 정보 저장하기
song = songs[0]

# %%
#  벅스 사이트에서 곡 제목 찾기 1
title = song.select('a')
len(title)

# %%
# 벅스 사이트에서 곡 제목 찾기 2
title = song.select('p > a')
len(title)

# %%
#  벅스 사이트에서 곡 제목 찾기 3
title = song.select('p.title > a')
len(title)

# %%
# 벅스 사이트에서 곡 제목 텍스트 출력하기
title = song.select('p.title > a')[0].text
title

# %%
#벅스 사이트에서 가수 이름 텍스트 출력하기
singer = song.select('p.artist > a')[0].text.strip()
singer

# %%
#  벅스 100위 노래 순위 정보 가져오기
songs = soup.select('table.byChart > tbody > tr')
for song in songs:
    title = song.select('p.title > a')[0].text
    singer = song.select('p.artist > a')[0].text
    print(title, singer, sep = '|')

# %%
# 반복문을 이용해 곡과 가수명을 song_data에 저장하기
song_data = []
rank = 1
songs = soup.select('table.byChart > tbody > tr')
for song in songs:
    title = song.select('p.title > a')[0].text
    singer = song.select('p.artist > a')[0].text
    song_data.append(['Bugs', rank, title, singer])
    rank = rank + 1

# %%
# song_data 리스트를 이용해 데이터프레임 만들기 
import pandas as pd
columns = ['서비스', '순위', '타이틀', '가수']
pd_data = pd.DataFrame(song_data, columns = columns)
pd_data.info()

# %%
# 크롤링 결과를 엑셀 파일로 저장하기
pd_data.to_excel('./bugs.xlsx', index=False)

# %% [markdown]
# # 지니 크롤링 결과를 엑셀 파일로 저장하기

# %%
#지니 사이트에 접속하기
from selenium import webdriver
from bs4 import BeautifulSoup

url = 'https://www.genie.co.kr/chart/top200'
driver.get(url) 

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
#  지니 사이트에서 곡 정보 찾기
songs = soup.select('table > tbody > tr')
len(songs)

# %%
# songs 태그 중 첫 번째 태그 출력해보기
print(songs[0])

# %%
#한 개의 곡 정보 저장하기
song = songs[0]

# %%
#지니 사이트에서 곡 제목 찾기
title = song.select('a.title')
len(title)

# %%
# 지니 사이트의 곡 제목 출력해보기 1
title = song.select('a.title')[0].text
title

# %%
# 지니 사이트의 곡 제목 출력해보기 2
title = song.select('a.title')[0].text.strip()
title

# %%
# 지니 사이트의 가수명 찾기
singer = song.select('a.artist')
len(singer)

# %%
# 지니 사이트의 가수명 출력해보기 1
singer = song.select('a.artist')[0].text
singer

# %%
#  지니 사이트의 가수명 출력해보기 2
songs = soup.select('tbody > tr')
for song in songs:
    title = song.select('a.title')[0].text.strip()
    singer = song.select('a.artist')[0].text
    print(title, singer, sep = '|')

# %%
# 반복문을 이용해 곡과 가수명을 song_data에 저장하기 
song_data = []
rank = 1
songs = soup.select('table > tbody > tr')
for song in songs:
    title = song.select('a.title')[0].text.strip()
    singer = song.select('a.artist')[0].text.strip()
    song_data.append(['Genie', rank, title, singer])
    rank = rank + 1

# %%
# 리스트를 이용해 엑셀 파일로 저장하기 
import pandas as pd

columns = ['서비스', '순위', '타이틀', '가수']
pd_data = pd.DataFrame(song_data, columns = columns)
pd_data.to_excel('./genie.xlsx', index=False)

# %% [markdown]
# # 멜론, 벅스, 지니 크롤링 엑셀 파일 통합하기

# %%
# 크롤링 결과가 담긴 엑셀 파일 통합하기 
import pandas as pd
excel_names = ['./genie.xlsx', './bugs.xlsx', './melon.xlsx']

appended_data = pd.DataFrame()
for name in excel_names:
    pd_data = pd.read_excel(name)
    appended_data = appended_data.append(pd_data)

# %%
#크롤링 결과 확인하기
appended_data.info()

# %%
# 통합한 크롤링 결과를 엑셀 파일로 저장하기 
appended_data.to_excel('./total.xlsx', index=False)

# %% [markdown]
# # 유튜브 랭킹 데이터

# %% [markdown]
# ### 유튜브 랭킹 데이터 수집하기

# %%
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin

# %%
from selenium import webdriver 
from bs4 import BeautifulSoup 
import time
import pandas as pd

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')        # Head-less 설정
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
browser = webdriver.Chrome('chromedriver', options=options)

# %%
url = "https://youtube-rank.com/board/bbs/board.php?bo_table=youtube" 
browser.get(url)

# %%
# 페이지 정보 가져오기
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
#BeautifulSoup으로 tr 태그 추출하기
channel_list = soup.select('tr') 
print(len(channel_list), '\n')
print(channel_list[0])

# %%
# tr 태그 확인하기
channel_list = soup.select('form > table > tbody > tr')
print(len(channel_list))

# %%
# 채널태그출력및태그구조 확인하기
channel = channel_list[0]
print(channel)

# %%
# 카테고리 정보 추출하기
category = channel.select('p.category')[0].text.strip()
print(category)

# %%
# 채널명 찾아오기
title = channel.select('h1 > a')[0].text.strip()
print(title)

# %%
# 구독자 수, View 수, 동영상 수 추출하기
subscriber = channel.select('.subscriber_cnt')[0].text
view = channel.select('.view_cnt')[0].text
video = channel.select('.video_cnt')[0].text

print(subscriber)
print(view)
print(video)

# %%
# # 반복문으로 채널 정보 추출하기
# channel_list = soup.select('tbody > tr') 
# for channel in channel_list:
#     title = channel.select('h1 > a')[0].text.strip()
#     category = channel.select('p.category')[0].text.strip()
#     subscriber = channel.select('.subscriber_cnt')[0].text
#     view = channel.select('.view_cnt')[0].text
#     video = channel.select('.video_cnt')[0].text 
#     print(title, category, subscriber, view, video)

# %%
# 페이지별 URL 만들기
page = 1
url = 'https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page={}'.format(page)
print(url)

# %%
#반복문으로 유튜브 랭킹 화면의 여러 페이지를 크롤링하기
results = []
for page in range(1,11):
    url = f"https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page={page}" 
    browser.get(url)
    time.sleep(2)
    html = browser.page_source
    soup = BeautifulSoup(html, 'html.parser')
    channel_list = soup.select('form > table > tbody > tr')
    for channel in channel_list:
        title = channel.select('h1 > a')[0].text.strip() 
        category = channel.select('p.category')[0].text.strip()
        subscriber = channel.select('.subscriber_cnt')[0].text 
        view = channel.select('.view_cnt')[0].text
        video = channel.select('.video_cnt')[0].text
        data = [title, category, subscriber, view, video]
        results.append(data)

# %%
# 데이터 칼럼명을 설정하고 엑셀 파일로 저장하기
df = pd.DataFrame(results)
df.columns = ['title', 'category', 'subscriber', 'view', 'video']
df.to_excel('./youtube_rank.xlsx', index = False)

# %% [markdown]
# ## 유튜브 랭킹 데이터 시각화하기

# %%
# 라이브러리 추가하기
import pandas as pd
import matplotlib.pyplot as plt

# %%
#  그래프에서 한글을 표기하기 위한 글꼴 변경(윈도우, macOS에 대해 각각 처리)
from matplotlib import font_manager, rc
import platform
if platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname = path).get_name()
    rc('font', family = font_name)
elif platform.system() == 'Darwin':
    rc('font', family = 'AppleGothic')
else:
    print('Check your OS system')

# %%
# 엑셀 파일 불러오기
df = pd.read_excel("./youtube_rank.xlsx")
df.head()

# %%
# 데이터 살펴보기
df.tail()

# %%
# 데이터 살펴보기
df['subscriber'][0:10]

# %%
#  데이터 살펴보기
df['subscriber'].str.replace('만', '0000')[0:10]

# %%
# replaced_subscriber 시리즈 문자열 변경하기
df['replaced_subscriber'] = df['subscriber'].str.replace('만', '0000')
df.head()

# %%
#  데이터 상세 정보
df.info()

# %%
#  Series 데이터 타입 변환하기
df['replaced_subscriber'] = df['replaced_subscriber'].astype('int')
df.info()

# %%
# 카테고리별 구독자 수, 채널 수 피봇 테이블 생성하기
pivot_df = df.pivot_table(index = 'category', values = 'replaced_subscriber', aggfunc = ['sum','count'])
pivot_df.head()

# %%
# 데이터프레임의 칼럼명 변경하기
pivot_df.columns = ['subscriber_sum', 'category_count']
pivot_df.head()

# %%
# 데이터프레임의인덱스초기화하기
pivot_df = pivot_df.reset_index()
pivot_df.head()

# %%
#  데이터프레임을내림차순정렬하기
pivot_df = pivot_df.sort_values(by='subscriber_sum', ascending=False)
pivot_df.head()

# %%
#  카테고리별구독자수시각화하기
plt.figure(figsize = (30,10))
plt.pie(pivot_df['subscriber_sum'], labels=pivot_df['category'], autopct='%1.1f%%')
plt.show()

# %%
#  카테고리별 채널 수 시각화하기
pivot_df = pivot_df.sort_values(by='category_count', ascending=False)
pivot_df.head()
plt.figure(figsize = (30,10))
plt.pie(pivot_df['category_count'], labels=pivot_df['category'], autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # 외국인 출입국 통계 데이터 구하기

# %% [markdown]
# ## 데이터 불러오기 및 전처리

# %% [markdown]
# ###파이썬에서 엑셀 데이터 불러오기

# %%
#  엑셀 데이터 불러오기
import pandas as pd 
kto_201901 = pd.read_excel('./kto_202210.xlsx', 
                          header=1,
                          usecols='A:G',
                          skipfooter=4)
kto_201901.head()

# %%
#  함수 활용 
kto_201901.tail()

# %% [markdown]
# ###데이터 전처리 하기

# %%
#  함수 활용
kto_201901.info()

# %%
# 함수 활용하기 
kto_201901.describe()

# %%
#  각 컬럼에서 0인 부분을 필터링
condition = (kto_201901['관광'] == 0) \
                | (kto_201901['상용'] == 0) \
                | (kto_201901['공용'] == 0) \
                | (kto_201901['유학/연수'] == 0) 
kto_201901[condition]

# %%
# 예제 4-6 기준년월 컬럼 생성 
kto_201901['기준년월'] = '2019-01'
kto_201901.head()

# %%
#  unique() 함수 활용하기 
kto_201901['국적'].unique()

# %%
# 대륙 목록 만들기 
continents_list = ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']
continents_list

# %%
#  대륙 목록에 해당하는 값 제외
condition = (kto_201901.국적.isin(continents_list) == False) 
kto_201901_country = kto_201901[condition]
kto_201901_country['국적'].unique()

# %%
# kto_201901_country 데이터 head() 함수로 확인 
kto_201901_country.head()

# %%
# index 재설정하기 
kto_201901_country_newindex = kto_201901_country.reset_index(drop=True) 
kto_201901_country_newindex.head()

# %%
#  대륙 컬럼값 만들기
continents = ['아시아']*25 + ['아메리카']*6 + ['유럽']*24 + ['오세아니아']*4 \
+ ['아프리카']*3 + ['기타대륙'] + ['교포']
print(continents)

# %%
#대륙 컬럼 생성
kto_201901_country_newindex['대륙'] = continents
kto_201901_country_newindex.head()

# %%
#  kto_201901_country_newindex 데이터 tail() 확인
kto_201901_country_newindex.tail()

# %%
# 관광객비율(%) 컬럼 생성 
kto_201901_country_newindex['관광객비율(%)'] = \
round(kto_201901_country_newindex['관광'] / kto_201901_country_newindex['계'] * 100, 1)
kto_201901_country_newindex.head()

# %%
# 관광객비율(%) 컬럼으로 내림차순 정렬  
kto_201901_country_newindex.sort_values(by='관광객비율(%)', ascending=False).head()

# %%
#관광객비율(%) 컬럼으로 오름차순 정렬
kto_201901_country_newindex.sort_values(by='관광객비율(%)', ascending=True).head()

# %%
# pivot_table() 함수 활용
kto_201901_country_newindex.pivot_table(values = '관광객비율(%)',
                                       index = '대륙',
                                       aggfunc = 'mean')

# %%
# 중국 국적만 필터링 
condition = (kto_201901_country_newindex['국적'] == '중국')
kto_201901_country_newindex[condition]

# %%
#  2019년 1월 우리나라 방문하는 전체 외국인 관광객 숫자 구하기 
tourist_sum = sum(kto_201901_country_newindex['관광'])
tourist_sum

# %%
# 전체비율(%) 컬럼 생성
kto_201901_country_newindex['전체비율(%)'] = \
    round(kto_201901_country_newindex['관광'] / tourist_sum * 100, 1)
kto_201901_country_newindex.head()

# %%
# 전체비율(%) 컬럼 기준으로 내림차순 정렬
kto_201901_country_newindex.sort_values('전체비율(%)', ascending=False).head()

# %% [markdown]
# ### 데이터 전처리 과정 함수로 만들기

# %%
# 함수 생성
def create_kto_data(yy, mm):  
    #1. 불러올 Excel 파일 경로를 지정
    file_path = '/content/drive/MyDrive/코딩 공부/colab/colab사용 파일/직장인을 위한 데이터 분석 실무 with 파이썬 사용파일/외국인출입/kto_202210.xlsx'.format(yy, mm)  
    
    # 2. Excel 파일 불러오기 
    df = pd.read_excel(file_path, header=1, skipfooter=4, usecols='A:G')
    
    # 3. "기준년월" 컬럼 추가 
    df['기준년월'] = '2022-10'.format(yy, mm) 
    
    # 4. "국적" 컬럼에서 대륙 제거하고 국가만 남기기 
    ignore_list = ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']    # 제거할 대륙명 선정하기 
    condition = (df['국적'].isin(ignore_list) == False)    # 대륙 미포함 조건 
    df_country = df[condition].reset_index(drop=True) 
    
    # 5. "대륙" 컬럼 추가 
    continents = ['아시아']*25 + ['아메리카']*6 + ['유럽']*24 + ['대양주']*4 + ['아프리카']*3 + ['기타대륙'] + ['교포']    # 대륙 컬럼 생성을 위한 목록 만들어 놓기 
    df_country['대륙'] = continents   
                       
    # 6. 국가별 "관광객비율(%)" 컬럼 추가
    df_country['관광객비율(%)'] = round(df_country.관광 / df_country.계 * 100, 1) 
                       
    # 7. "전체비율(%)" 컬럼 추가
    tourist_sum = sum(df_country['관광'])
    df_country['전체비율(%)'] = round(df_country['관광'] / tourist_sum * 100, 1)
    
    # 8. 결과 출력
    return(df_country)

# %%
#  create_kto_data() 함수를 활용해서 2018년 12월 데이터 불러오기  
kto_test = create_kto_data(2022, 10)
kto_test.head()

# %% [markdown]
# ### 반복문(for문)을 통해 다수의 엑셀 데이터 불러와서 합치기

# %%
# 이중 반복문으로 기준년월 출력
for yy in range(2010, 2021): 
    for mm in range(1, 13): 
        yymm = '{}{}'.format(yy, mm)
        print(yymm)

# %%
#숫자 1 출력
mm = 1 
print(mm)

# %%
#zfill() 함수 이용 - 1(0을 포함한 두 자리로 출력하기)
print(str(mm).zfill(2))

# %%
#  zfill() 함수 이용 - 2(0을 포함한 3자리, 4자리로 출력하기)
print(str(mm).zfill(3))
print(str(mm).zfill(4))

# %%
#6자리로 정렬하여 기준년월 출력하기 
for yy in range(2010, 2021):
    for mm in range(1, 13):
        mm_str = str(mm).zfill(2)
        yymm = '{}{}'.format(yy, mm_str)
        print(yymm)

# %%
df = pd.DataFrame()

# %%
for yy in range(2010, 2021):
    for mm in range(1, 13):
        temp = create_kto_data(str(yy), str(mm).zfill(2))
        df = df.append(temp, ignore_index=True)

# %%
#  df 데이터 head() 함수로 확인하기
df.head()

# %%
#  df 데이터 tail() 함수로 확인
df.tail()

# %%
# 통합 데이터 생성
df = pd.DataFrame()

# 패턴 분석결과를 이중 반복문을 통해 구현 
for yy in range(2010, 2021):
    for mm in range(1, 13):
        # try 이하 구문을 실행 
        try:
            # 앞서 만든 create_kto_data 함수로 Excel 데이터를 temp 에 불러오기 
            temp = create_kto_data(str(yy), str(mm).zfill(2))

            # temp 로 불러온 데이터를 df 밑으로 추가하기 
            df = df.append(temp, ignore_index=True)
            
        # 만약 try 구문에서 에러가 발생하면 except 이후를 실행 
        except:
            pass

# %%
# df 데이터 info() 함수로 확인
df.info()

# %% [markdown]
# ###통합 데이터를 엑셀 파일로 저장하기

# %%
# df 데이터 엑셀로 저장하기
#코드는 아래와 같지만 파일상의의 이유로 실행시키지 않음
#df.to_excel('/content/drive/MyDrive/코딩 공부/colab/colab사용 파일/직장인을 위한 데이터 분석 실무 with 파이썬 사용파일/외국인출입/kto_total.xlsx', index = False)

# %% [markdown]
# ### 국적별 필터링된 데이터를 엑셀 파일로 저장하기

# %%
# 중국인 관광객 데이터만 필터링하기 
condition = (df['국적'] == '중국')
df_filter = df[condition]
df_filter.head()

# %%
# 중국인 관광객 파일 저장 
#file_path = '파일 경로'
#df_filter.to_excel(file_path, index = False)

# %%
# 예제 4-39 국가 리스트 만들기
cntry_list = df['국적'].unique()
cntry_list

# %%
# 예제 4-40 개별 국적별 관광객 데이터 저장하기 
#for cntry in cntry_list: 
    # 국적으로 필터링 
#    condition = (df['국적'] == cntry)
#    df_filter = df[condition]
    
    # 국적이름을 반영한 파일명 만들기 
#    file_path = '파일 경로'.format(cntry)
    
#    # 정해 놓은 파일명으로 저장하기 
#    df_filter.to_excel(file_path, index = False)

# %% [markdown]
# ## 데이터 시각화 하기

# %% [markdown]
# ###시계열 그래프 그리기

# %%
#  kto_total.xlsx 파일 df로 불러오기 
import pandas as pd 
df = pd.read_excel('./kto_total.xlsx')
df.head()

# %%
#그래프에서 한글 표기를 위한 글자체 변경(윈도우, 맥os 각각의 경우에 대해서 처리)
from matplotlib import font_manager, rc
import platform 

if platform.system() == 'Windows': 
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
else: 
    print('Check your OS system')

# %%
#matplotlib 라이브러리 불러오기 
import matplotlib.pyplot as plt

# %%
#  중국 국적 데이터 필터링하기 
condition = (df['국적'] == '중국')
df_filter = df[condition]
df_filter.head()

# %%
# 시계열 그래프 그리기 1
plt.plot(df_filter['기준년월'], df_filter['관광'])
plt.show()

# %%
# 시계열 그래프 그리기 2(꾸미기)
## 그래프 크기 조절 
plt.figure(figsize = (12, 4))

## 그래프 내용 설정 
plt.plot(df_filter['기준년월'], df_filter['관광'])

## 그래프 타이틀, X축, Y축 이름 달기 
plt.title('중국 국적의 관광객 추이')
plt.xlabel('기준년월')
plt.ylabel('관광객수')

## x 축 눈금 값 설정 
plt.xticks(['2010-01', '2011-01', '2012-01', '2013-01', '2014-01', '2015-01', '2016-01', '2017-01', '2018-01', '2019-01', '2020-01'])

## 그래프 표현하기 
plt.show()

# %%
# 우리나라 방문하는 외국인 관관객 중 상위 5개 국가의 리스트 만들기
cntry_list = ['중국', '일본', '대만', '미국', '홍콩']

# %%
# 반복문으로 여러 그래프 그리기 
for cntry in cntry_list: 
    # 국적 관광객만 추출 
    condition = (df['국적'] == cntry)
    df_filter = df[condition]

    # 그래프 그리기 
    ## 그래프 크기 조절 
    plt.figure(figsize = (12, 4))
    
    ## 그래프 내용 설정 
    plt.plot(df_filter['기준년월'], df_filter['관광'])

    ## 그래프 타이틀, X축, Y축 이름 달기 
    plt.title('{} 국적의 관광객 추이'.format(cntry))
    plt.xlabel('기준년월')
    plt.ylabel('관광객수')

    ## x 축 눈금 값 설정 
    plt.xticks(['2010-01', '2011-01', '2012-01', '2013-01', '2014-01', '2015-01', '2016-01', '2017-01', '2018-01', '2019-01', '2020-01'])

    ## 그래프 표현하기 
    plt.show()

# %% [markdown]
# ###히트맵 그래프 그리기

# %%
#  데이터 head() 함수로 살펴보기 
df.head()

# %%
#str.slice() 함수를 이용해 연도, 월 컬럼 만들기 
df['년도'] = df['기준년월'].str.slice(0,4)
df['월'] = df['기준년월'].str.slice(5, 7)
df.head()

# %%
# 중국인 관광객 필터링
condition = (df['국적'] == '중국')
df_filter = df[condition]
df_filter.head()

# %%
#pivot_table() 함수 이용
df_pivot = df_filter.pivot_table(values = '관광'
                         , index = '년도'
                         , columns = '월')

df_pivot

# %%
#히트맵 그래프 그리기에 필요한 라이브러리 import 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#  히트맵 그리프 그리기 
## 그래프 크기 설정 
plt.figure(figsize = (16, 10))

## 히트맵 그래프 그리기 
sns.heatmap(df_pivot, annot = True, fmt = '.0f', cmap = 'rocket_r')

## 그래프 타이틀 달기 
plt.title('중국 관광객 히트맵')

## 그래프 표현 
plt.show()

# %%
# 반복문으로 상위 5개국에 대한 히트맵 그래프 그리기 
for cntry in cntry_list: 
    condition = (df['국적'] == cntry)
    df_filter = df[condition]
    
    df_pivot = df_filter.pivot_table(values = '관광'
                             , index = '년도'
                             , columns = '월')
    
    # 그래프 크기 설정 
    plt.figure(figsize = (16, 10))

    # 히트맵 그래프 그리기 
    sns.heatmap(df_pivot, annot = True, fmt = '.0f', cmap = 'rocket_r')

    # 그래프 타이틀 달기 
    plt.title('{} 관광객 히트맵'.format(cntry))

    # 그래프 표현 
    plt.show()

# %% [markdown]
# # 가장 뜨는 제주도 핫플레이스는 어디일까

# %% [markdown]
# ## 인스타그램 크롤링

# %% [markdown]
# ### 인스타그램 접속 후 로그인하기

# %%
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin

# %%
from selenium import webdriver

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')        # Head-less 설정
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome('chromedriver', options=options)

# %%
#  인스타그램 접속하기
import time
from selenium.webdriver import ActionChains
# 인스타그램 접속하기
driver.get('https://www.instagram.com/?hl=ko')
time.sleep(2)

# %%
# 02. 로그인
#경로 지정
id_box = driver.find_element("css selector", "#loginForm > div > div:nth-child(1) > div > label > input")


#id_box = driver.find_element_by_css_selector("#loginForm > div > div:nth-child(1) > div > label > input")   #아이디 입력창

password_box = driver.find_element("css selector", "#loginForm > div > div:nth-child(2) > div > label > input")

#password_box = driver.find_element_by_css_selector("#loginForm > div > div:nth-child(2) > div > label > input")     #비밀번호 입력창

login_button = driver.find_element("css selector", "#loginForm > div > div:nth-child(3) > button > div")    #로그인 버튼

#동작 제어
act = ActionChains(driver)      #동작 명령어 지정
act.send_keys_to_element(id_box, 'leetae04kr').send_keys_to_element(password_box, 'dlxodud5573').click(login_button).perform()     #아이디 입력, 비밀 번호 입력, 로그인 버튼 클릭 수행
time.sleep(2)

# %% [markdown]
# ### 인스타그램 검색결과 URL 만들어서 접속하기

# %%
# 검색결과 URL 만드는 함수
def insta_searching(word):
    
    url = 'https://www.instagram.com/explore/tags/' + word
    return url

# %%
# 검색결과 페이지 접속하기
word = "제주도맛집"
url = insta_searching(word)
driver.get(url)

# %% [markdown]
# ### 첫 번째 게시글 열기

# %%
# HTML에서 첫번째 게시글 찾아 클릭하기
# 인스타그램 사이트 개편에 따른 태그 정보 수정(updated 2022.10.02)
def select_first(driver):
    first = driver.find_element('css selector', " div._aaq8 > div > div > div:nth-child(1) > div:nth-child(1) > a")  # selenium 명령어 변경으로 인한 코드 수정 (updated 2022.10.01) 
    driver.execute_script("arguments[0].click();", first)
    time.sleep(3)

select_first(driver)

# %% [markdown]
# ### 게시글 정보 가져오기

# %%
import re
from bs4 import BeautifulSoup
import unicodedata
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
date = soup.select('div._ae2s._ae3v._ae3w > div._ae5q._ae5r._ae5s > ul > div > li > div > div > div._a9zr > div._a9zs > span')
date=soup.find('div._ae2s._ae3v._ae3w > div._ae5q._ae5r._ae5s > ul > div > li > div > div > div._a9zr > div._a9zs > span')
print(date)

# %%
# 예제 5-7 게시글 정보 가져오기
# 인스타그램 사이트 개편에 따른 태그 정보 수정(updated 2022.10.02)

import re
from bs4 import BeautifulSoup
import unicodedata

def get_content(driver):
    # ① 현재 페이지 html 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    # ② 본문 내용 가져오기
    try:
      content = soup.select('div._ae5q._ae5r._ae5s > ul > div > li > div > div > div._a9zr > div._a9zs > span')[0].text  
      content = unicodedata.normalize('NFC', content) 
    except:
        content = ' '
    # ③ 본문 내용에서 해시태그 가져오기(정규식 활용)
    tags = re.findall(r'#[^\s#,\\]+', content)  
    # ④ 작성일자 정보 가져오기
    date = soup.select(' div._ab8w._ab94._ab99._ab9f._ab9m._ab9p._abaj._abb-._abcm > div > time')
    # ⑤ 좋아요 수 가져오기
    try:
        like = soup.select('div._aacl._aaco._aacw._aacx._aada._aade > span')[0].text
    except:
        like = 0
    # ⑥ 위치정보 가져오기
    try: 
        place = soup.select('div._aaqm')[0].text
        place = unicodedata.normalize('NFC', place)
    except:
        place = ''
    # ⑦ 수집한 정보 저장하기
    data = [content, date, like, place, tags]
    return data

get_content(driver)

# %% [markdown]
# ### 다음 게시글 열기

# %% [markdown]
# ### 여러 게시글 정보 수집하기

# %% [markdown]
# ### 여러 엑셀 파일의 중복을 제거한 후 통합 저장

# %% [markdown]
# ##워드클라우드

# %% [markdown]
# ###해시태그 데이터 불러오기

# %%
# 예제 5-14 크롤링 결과 중 해시태그 데이터 불러오기
import pandas as pd
raw_total = pd.read_excel('/content/drive/MyDrive/코딩 공부/colab/colab사용 파일/직장인을 위한 데이터 분석 실무 with 파이썬 사용파일/인스타/1_crawling_raw.xlsx')
raw_total['tags'] [:3]

# %%
# 해시태그 통합 저장하기
tags_total = []

for tags in raw_total['tags']:
    tags_list = tags[2:-2].split("', '")
    for tag in tags_list:
        tags_total.append(tag)

# %% [markdown]
# ###해시태그 출현 빈도 집계

# %%
#빈도수 집계하기(Counter)
from collections import Counter
tag_counts = Counter(tags_total)

# %%
# 가장 많이 사용된 해시태그 살펴보기 
tag_counts.most_common(50)

# %%
# 데이터 정제하기
STOPWORDS = ['#일상', '#선팔', '#제주도', '#jeju', '#반영구', '#제주자연눈썹',
'#서귀포눈썹문신', '#제주눈썹문신', '#소통', '#맞팔']

tag_total_selected = []
for tag in tags_total:
    if tag not in STOPWORDS:
        tag_total_selected.append(tag)
        
tag_counts_selected = Counter(tag_total_selected)
tag_counts_selected.most_common(50)

# %% [markdown]
# ###막대차트로 해시태그 살펴보기

# %%
# 예제 5-19 시각화 라이브러리 호출 및 환경 설정(한글 폰트)
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
import sys

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
# 예제 5-20 데이터 준비하기
tag_counts_df = pd.DataFrame(tag_counts_selected.most_common(30))
tag_counts_df.columns = ['tags', 'counts']

# %%
# 예제 5-21 막대 차트 그리기
plt.figure(figsize=(10,8)) 
sns.barplot(x='counts', y='tags', data = tag_counts_df)

# %% [markdown]
# ###워드 클라우드 그리기

# %%
# 예제 5-22 워드클라우드 라이브러리 불러오기
import matplotlib.pyplot as plt
from wordcloud import WordCloud    # 에러시  ! pip install wordcloud 실행
import platform

# %%
font_path = "./Gugi-Regular.ttf"

# %%
# 예제 5-23 워드클라우드 만들기
wordcloud=WordCloud(font_path= font_path, 
                    background_color="white",
                    max_words=100,
                    relative_scaling= 0.3,
                    width = 800,
                    height = 400
                 ).generate_from_frequencies(tag_counts_selected)  
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis('off')
#plt.savefig('./files/2_tag-wordcloud.png')

# %% [markdown]
# ##지도시각화

# %% [markdown]
# ###데이터 준비

# %%
# 크롤링 데이터 불러오기
import pandas as pd
raw_total = pd.read_excel('./1_crawling_raw.xlsx')
raw_total.head()

# %%
# 위치정보 가져오기
location_counts = raw_total['place'].value_counts( )
location_counts

# %%
#등록된 위치정보별 빈도수 데이터
location_counts_df = pd.DataFrame(location_counts)
location_counts_df.head()

# %%
#위치정보 빈도수 데이터 저장하기
location_counts_df.to_excel('./3_location_counts.xlsx')

# %%
#위치정보 종류 확인하기
locations = list( location_counts.index )
locations

# %% [markdown]
# ###카카오 검색 API를 활용한 장소 검색

# %%
# 예제 5-29 카카오 검색 API 사용 예시

import requests

searching = '합정 스타벅스'
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)

headers = {
    "Authorization": "KakaoAK 218adbf493e30e07f146331adb27aaee"     
    # 입력시 반드시  KakaoAK 뒤에 한 칸 띄우고 API키 값을 적어야 합니다. 
}

places = requests.get(url, headers = headers).json()['documents']
places

# %%
# 카카오 로컬 API를 활용한 장소 검색 함수 만들기
def find_places(searching):
    # ① 접속URL 만들기
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
    # ② headers 입력하기
    headers = {
    "Authorization": "KakaoAK 218adbf493e30e07f146331adb27aaee"
    }
    # ③ API 요청&정보 받기
    places = requests.get(url, headers = headers).json()['documents']
    # ④ 필요한 정보 선택하기
    place = places[0] 
    name = place['place_name']
    x=place['x']
    y=place['y']
    data = [name, x, y, searching] 

    return data

# %%
#제주공항 검색 예시
data = find_places('제주공항')
data

# %%
# 반복작업 진행시 진행바 표시하기위한 라이브러리 tqdm 활용하기
# ! pip install tqdm   # tqdm 라이브러리 설치하기
from tqdm.notebook import tqdm

# %%
# 인스타그램 위치명 위치정보 검색하기
#### 검색시 시간이 많이 걸려, 현재 작업 진행현황을 볼 수 있도록,  tqdm_notebook 추가 했습니다.

import time
locations_inform = [ ]
for location in tqdm(locations):
    try:
        data = find_places(location)       
        locations_inform.append(data) 
        time.sleep(0.5) 
    except:
        pass
locations_inform

# %%
# 위치정보 저장하기
locations_inform_df = pd.DataFrame(locations_inform)
locations_inform_df.columns = ['name_official','경도','위도','인스타위치명']
locations_inform_df.to_excel('./3_locations.xlsx', index=False)

# %%
# 예제 5-34 인스타 게시량 및 위치정보 데이터 불러오기
location_counts_df = pd.read_excel('./3_location_counts.xlsx', index_col = 0)
locations_inform_df = pd.read_excel('./3_locations.xlsx')

# %%
# 예제 5-35 위치 데이터 병합하기
location_data = pd.merge(locations_inform_df, location_counts_df, 
                         how = 'inner', left_on = 'name_official', right_index=True)

location_data.head()

# %%
# 예제 5-36 데이터 중복 점검하기
location_data['name_official'].value_counts()

# %%
# 예제 5-37 장소 이름 기준 병합하기
location_data = location_data.pivot_table(index = ['name_official','경도','위도'], values = 'place', aggfunc='sum')
location_data.head()

# %%
# 예제 5-38 병합한 데이터 저장하기
location_data.to_excel('./3_location_inform.xlsx')

# %% [markdown]
# ###folium을 이용한 지도 시각화 ① - 개별 표시

# %%
# 데이터 불러오기
location_data = pd.read_excel('./3_location_inform.xlsx')
location_data.info()

# %%
#  지도 표시하기
### 변수명 수정  수정일자 2020.02.17

import folium

Mt_Hanla =[33.362500, 126.533694]
map_jeju = folium.Map(location = Mt_Hanla, zoom_start = 11)

for i in range(len(location_data)):
    name = location_data ['name_official'][i]    # 공식명칭
    count = location_data ['place'][i]           # 게시글 개수
    size = int(count)*2
    long = float(location_data['위도'][i])      
    lat = float(location_data['경도'][i])       
    folium.CircleMarker((long,lat), radius = size, color='red', popup=name).add_to(map_jeju)
    
map_jeju

# %% [markdown]
# ##특정 단어 포함 게시글 찾기

# %% [markdown]
# ###데이터 준비

# %%
# 예제 5-44 크롤링 데이터 불러오기
import pandas as pd
raw_total = pd.read_excel('./1_crawling_raw.xlsx')
raw_total.head()

# %% [markdown]
# ### 단어 선택하기

# %%
#추출 단어 포함하는 데이터 선택하기
select_word = '해돋이'

check_list = []
for content in raw_total['content']:
    if select_word in content:
        check_list.append(True)
    else:
        check_list.append(False)
        
select_df = raw_total[check_list]
select_df.head()

# %%
# 선택 데이터 확인하기
for i in select_df.index:
    print(select_df.loc[i, 'content'])
    print('-'*50)

# %%
# # 선택 데이터 저장하기
# fpath = f'폴더 선택'
# select_df.to_excel(fpath)

# %%
# # 여러개의 단어 선택/추출/저장하기
# select_word_list = ['해돋이','박물관','힐링','게스트하우스','섭지코지']

# for select_word in select_word_list:
#     check_list = []
#     for content in raw_total['content']:
#         if select_word in content:
#             check_list.append(True)
#         else:
#             check_list.append(False)

#     select_df = raw_total[check_list]
#     fpath = f'폴더선택'
#     select_df.to_excel(fpath)

# %% [markdown]
# # 왜 우리 동네에는 스타벅스가 없을까?

# %% [markdown]
# ##데이터 수집

# %% [markdown]
# ###크롤링을 이용한 서울시 스타벅스 매장 목록 데이터 생성

# %%
#  라이브러리 임포트
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
# driver = webdriver.Chrome('../chromedriver')
url = 'https://www.istarbucks.co.kr/store/store_map.do?disp=locale'
driver.get(url)

# %%
# webdriver로 ‘대구’ 버튼 요소를 찾아 클릭
seoul_btn = '#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(4) > a'
driver.find_element('css selector', seoul_btn).click() # selenium 명령어 변경으로 인한 코드 수정 (updated 2022.10.03)

# %%
# 예제 6-4  webdriver로 ‘전체’ 버튼 요소를 찾아 클릭
all_btn = '#mCSB_2_container > ul > li:nth-child(1) > a'
driver.find_element('css selector', all_btn).click()  # selenium 명령어 변경으로 인한 코드 수정 (updated 2022.10.03)

# %%
# 예제 6-5  BeautifulSoup으로 HTML 파서 만들기
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
#  select()를 이용해 원하는 HTML 태그를 모두 찾아오기
starbucks_soup_list = soup.select('li.quickResultLstCon')
print(len(starbucks_soup_list))

# %%
# 태그 문자열 살펴보기
starbucks_soup_list[0]

# %%
# 스타벅스 매장 정보 샘플 확인
startbucks_store = starbucks_soup_list[0]
name = startbucks_store.select('strong')[0].text.strip()
lat = startbucks_store['data-lat'].strip()
lng = startbucks_store['data-long'].strip()
store_type = startbucks_store.select('i')[0]['class'][0][4:]
address = str(startbucks_store.select('p.result_details')[0]).split('<br/>')[0].split('>')[1]
tel = str(startbucks_store.select('p.result_details')[0]).split('<br/>')[1].split('<')[0]

print(name)         # 매장명
print(lat)          # 위도
print(lng)          # 경도
print(store_type)   # 매장 타입
print(address)      # 주소
print(tel)          # 전화번호

# %%
# 대구시 스타벅스 매장 목록 데이터 만들기
starbucks_list = []
for item in starbucks_soup_list:
    name = item.select('strong')[0].text.strip();
    lat = item['data-lat'].strip()
    lng = item['data-long'].strip()
    store_type = item.select('i')[0]['class'][0][4:]
    address = str(item.select('p.result_details')[0]).split('<br/>')[0].split('>')[1]
    tel = str(item.select('p.result_details')[0]).split('<br/>')[1].split('<')[0]
    
    starbucks_list.append( [ name, lat, lng, store_type, address, tel])

# %%
#  pandas의 데이터프레임 생성
columns = ['매장명','위도','경도','매장타입', '주소','전화번호']
seoul_starbucks_df = pd.DataFrame(starbucks_list, columns = columns)
seoul_starbucks_df.head()

# %%
# 데이터프레임의 요약 정보 확인
seoul_starbucks_df.info()

# %%
#엑셀로 저장
seoul_starbucks_df.to_excel('./daegu_starbucks_list.xlsx', index=False)

# %% [markdown]
# ###서울열린데이터광장 공공데이터 수집 및 정리

# %%
#  서울시 구별 주민등록인구통계 데이터 가져오기  * txt파일 열기로 코드 변경(updated 2021.01.07)
sgg_pop_df = pd.read_csv('./report.txt', sep='\t', header=2)
columns = {
    '기간': 'GIGAN',
    '자치구': 'JACHIGU',
    '계': 'GYE_1',
    '계.1': 'GYE_2',
    '계.2': 'GYE_3',
    '남자': 'NAMJA_1',
    '남자.1': 'NAMJA_2',
    '남자.2': 'NAMJA_3',
    '여자': 'YEOJA_1',
    '여자.1': 'YEOJA_2',
    '여자.2': 'YEOJA_3',
    '세대': 'SEDAE',
    '세대당인구': 'SEDAEDANGINGU',
    '65세이상고령자': 'N_65SEISANGGORYEONGJA'
}
sgg_pop_df.rename(columns = columns, inplace = True)

# %%
# 서울시 시군구 인구 데이터 살펴보기
sgg_pop_df.head()

# %%
#서울시 구별 주민등록인구 데이터프레임의 요약 정보 확인
sgg_pop_df.info()

# %%
# 필요없는 데이터 제거
condition = sgg_pop_df['JACHIGU'] != '합계'
sgg_pop_df_selected = sgg_pop_df[condition]
sgg_pop_df_selected.head()

# %%
# 서울시 구별 주민등록인구 데이터프레임의 요약 정보 확인
sgg_pop_df_selected.info()

# %%
#  분석에 필요한 칼럼 선택
columns = ['JACHIGU', 'GYE_1']
sgg_pop_df_final = sgg_pop_df_selected[columns]

# %%
#  선택된 칼럼 확인
sgg_pop_df_final.head()

# %%
# 데이터프레임의 칼럼명 변경
sgg_pop_df_final.columns = ['시군구명', '주민등록인구']
sgg_pop_df_final.info()
sgg_pop_df_final.head()

# %%
# 엑셀로 저장
sgg_pop_df_final.to_excel('./sgg_pop.xlsx', index=False)
# 예제 6-34 서울시 동별 사업체현황 통계 데이터 가져오기
sgg_biz_df = pd.read_csv('./report2.txt', sep='\t', header=2)
columns = {
    '기간': 'GIGAN',
    '자치구': 'JACHIGU',
    '동': 'DONG',
    '사업체수': 'SAEOPCHESU_1',
    '여성대표자': 'YEOSEONGDAEPYOJA',
    '계': 'GYE',
    '남': 'NAM',
    '여': 'YEO'
}
sgg_biz_df.rename(columns = columns, inplace = True)
sgg_biz_df.head(10)

# %%
#   시군구별 사업체 현황 데이터 추출
condition = sgg_biz_df['DONG'] == '소계'
sgg_biz_df_selected = sgg_biz_df[condition]
sgg_biz_df_selected.head(10)

# %%
#필요없는 칼럼 제거
columns = ['JACHIGU', 'GYE', 'SAEOPCHESU_1']
sgg_biz_df_final = sgg_biz_df_selected [columns]
sgg_biz_df_final.columns = ['시군구명', '종사자수','사업체수']
sgg_biz_df_final.head()

# %%
#  데이터프레임의 인덱스 초기화
sgg_biz_df_final = sgg_biz_df_final.reset_index(drop=True)
sgg_biz_df_final.head()

# %%
# 엑셀로 저장
sgg_biz_df_final.to_excel('./sgg_biz.xlsx', index=False)

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# ###서울시 스타벅스 매장 목록, 인구, 사업체 데이터에 시군구명, 시군구코드 추가

# %%
# 서울시 스타벅스 매장 목록이 담긴 엑셀 파일 불러오기
import pandas as pd
seoul_starbucks = pd.read_excel('./seoul_starbucks_list.xlsx', header=0)
seoul_starbucks.head()

# %%
# 스타벅스 주소 정보에서 시군구명 추출
sgg_names = []
for address in seoul_starbucks['주소']:
    sgg = address.split()[1]
    sgg_names.append(sgg)
seoul_starbucks['시군구명'] = sgg_names
seoul_starbucks.head()

# %%
#  엑셀로 저장
seoul_starbucks.to_excel('./seoul_starbucks_list.xlsx', index=False)

# %% [markdown]
# ###스타벅스 분석 데이터 만들기

# %%
# 라이브러리 임포트
import pandas as pd

# %%
# 시군구 목록 데이터 불러오기
seoul_sgg = pd.read_excel('./seoul_sgg_list.xlsx')
seoul_sgg.head()

# %%
# 서울시 스타벅스 매장 목록 데이터 불러오기
seoul_starbucks = pd.read_excel('./seoul_starbucks_list.xlsx')
seoul_starbucks.head()

# %%
# 시군구별 스타벅스 매장 수 세기
starbucks_sgg_count = seoul_starbucks.pivot_table(
                                                index = '시군구명', 
                                                values='매장명', 
                                                aggfunc='count'
                                                ).rename(columns={'매장명':'스타벅스_매장수'})
starbucks_sgg_count.head()

# %%
#서울시 시군구별 인구통계 데이터 불러오기
seoul_sgg_pop = pd.read_excel('./sgg_pop.xlsx')
seoul_sgg_pop.head()

# %%
#서울시 시군구 목록 데이터에 서울시 시군구별 인구통계 데이터를 병합
seoul_sgg = pd.merge(seoul_sgg, seoul_sgg_pop, how='left', on='시군구명')
seoul_sgg.head()

# %%
# 서울시 시군구 목록 데이터에 서울시 시군구별 사업체 수 통계 데이터를 병합
seoul_sgg_biz = pd.read_excel('./sgg_biz.xlsx')
seoul_sgg = pd.merge(
    seoul_sgg, 
    seoul_sgg_biz,
    how='left',
    on='시군구명'
)
seoul_sgg.head()

# %%
# 병합 결과를 엑셀 파일로 저장
seoul_sgg.to_excel('./seoul_sgg_stat.xlsx', index=False)

# %% [markdown]
# ## 데이터 시각화

# %% [markdown]
# ###스타벅스 매장분포 시각화

# %%
#라이브러리 임포트
import pandas as pd
import folium
import json

# %%
#   folium 설치
! pip install folium

# %%
#서울시 스타벅스 매장 목록 데이터 불러오기
seoul_starbucks = pd.read_excel('seoul_starbucks_list.xlsx')
seoul_starbucks.head()

# %%
# folium을 이용한 지도 생성
starbucks_map = folium.Map(
    location=[37.573050, 126.979189],
    tiles='Stamen Terrain',
    zoom_start=11
)
starbucks_map

# %%
# 지도에 스타벅스 매장 위치를 나타내는 서클 마커 그리기
for idx in seoul_starbucks.index:
    lat = seoul_starbucks.loc[idx, '위도']
    lng = seoul_starbucks.loc[idx, '경도']

    folium.CircleMarker(
        location=[lat, lng],
        fill = True, 
        fill_color='green', 
        fill_opacity=1,
        color='yellow', 
        weight=1,
        radius=3
    ).add_to(starbucks_map)

starbucks_map

# %%
# 스타벅스 매장 타입별 위치 서클 마커 그리기
starbucks_map2 = folium.Map(
    location=[37.573050, 126.979189],
    tiles='Stamen Terrain',
    zoom_start=11
)

for idx in seoul_starbucks.index:
    lat = seoul_starbucks.loc[idx, '위도']
    lng = seoul_starbucks.loc[idx, '경도']
    store_type = seoul_starbucks.loc[idx, '매장타입']
    
    # 매장 타입별 색상 선택을 위한 조건문
    fillColor = ''
    if store_type == 'general':
        fillColor = 'gray'
        size = 1
    elif store_type == 'reserve':
        fillColor = 'blue'
        size = 5
    elif store_type == 'generalDT':
        fillColor = 'red'
        size = 5

    folium.CircleMarker(
        location=[lat, lng],
        color=fillColor,
        fill = True,
        fill_color = fillColor, 
        fill_opacity = 1,
        weight = 1,
        radius = size
    ).add_to(starbucks_map2)

starbucks_map2

# %% [markdown]
# ###시군구별 스타벅스 매장 수 시각화

# %%
# 라이브러리 임포트
import pandas as pd
import folium
import json

# %%
#서울시 시군구별 통계 데이터 불러오기
seoul_sgg_stat = pd.read_excel('/content/drive/MyDrive/코딩 공부/colab/colab사용 파일/직장인을 위한 데이터 분석 실무 with 파이썬 사용파일/스타벅스/seoul_sgg_stat.xlsx', thousands = ',')
seoul_sgg_stat.head()

# %%
#서울시 시군구 행정 경계 지도 파일 불러오기
sgg_geojson_file_path = '/content/drive/MyDrive/코딩 공부/colab/colab사용 파일/직장인을 위한 데이터 분석 실무 with 파이썬 사용파일/스타벅스/seoul_sgg.geojson'
seoul_sgg_geo = json.load(open(sgg_geojson_file_path, encoding='utf-8'))
seoul_sgg_geo['features'][0]['properties']

# %%
# folium 지도 생성
starbucks_bubble = folium.Map(
    location=[37.573050, 126.979189], tiles ='CartoDB positron' , zoom_start=11 )
#     tiles='CartoDB dark_matter',
#     tiles='CartoDB',
    
# )

# %%
starbucks_bubble

# %%
# 서울시 시군구 경계 지도 그리기
def style_function(feature):
    return {
        'opacity': 0.7,
        'weight': 1,
        'color': 'white',
        'fillOpacity':0,
        'dashArray': '5, 5',
    }

folium.GeoJson(
    seoul_sgg_geo,
    style_function=style_function
).add_to(starbucks_bubble)

starbucks_bubble

# %%
#  서울시 시군구별 스타벅스 평균 매장 수 계산
starbucks_mean = seoul_sgg_stat['사업체수'].mean()
print(starbucks_mean)

# %%
#서울시 시군구별 스타벅스 매장 수를 버블 지도로 시각화
for idx in seoul_sgg_stat.index:
    lat = seoul_sgg_stat.loc[idx, '위도']
    lng = seoul_sgg_stat.loc[idx, '경도']
    count = seoul_sgg_stat.loc[idx, '사업체수']

    if count > starbucks_mean:
        fillColor = 'red'
    else:
        fillColor = 'blue'
    
    folium.CircleMarker(
        location=[lat, lng], 
        color='#FFFF00',
        fill_color=fillColor, 
        fill_opacity=0.7,
        weight=1.5,
        radius=count/2
    ).add_to(starbucks_bubble)

starbucks_bubble

# %%
#서울시 시군구별 스타벅스 매장 수를 단계구분도로 시각화
sgg_geojson_file_path = '/content/drive/MyDrive/코딩 공부/colab/colab사용 파일/직장인을 위한 데이터 분석 실무 with 파이썬 사용파일/스타벅스/seoul_sgg.geojson'
seoul_sgg_geo_2 = json.load(open(sgg_geojson_file_path, encoding='utf-8'))
starbucks_choropleth = folium.Map(
    location=[37.573050, 126.979189],
    tiles='CartoDB dark_matter',
    zoom_start=11
)

folium.Choropleth(
    geo_data=seoul_sgg_geo_2,
    data=seoul_sgg_stat,
    columns=['시군구명', '사업체수'],
    fill_color = 'YlGn',
    fill_opacity=0.7,
    line_opacity=0.5,
    key_on='properties.SIG_KOR_NM'
    ).add_to(starbucks_choropleth)

starbucks_choropleth

# %% [markdown]
# ###스타벅스 매장 수와 인구수 비교

# %%
#  라이브러리 임포트
import pandas as pd
import json
import folium

# %%
#  서울시 시군구별 통계 데이터 불러오기
seoul_sgg_stat = pd.read_excel('/content/drive/MyDrive/코딩 공부/colab/colab사용 파일/직장인을 위한 데이터 분석 실무 with 파이썬 사용파일/스타벅스/seoul_sgg_stat.xlsx', thousands = ',')
seoul_sgg_stat.head()

# %%
#서울시 시군구 행정 경계 지도 파일 불러오기
sgg_geojson_file_path = '/content/drive/MyDrive/코딩 공부/colab/colab사용 파일/직장인을 위한 데이터 분석 실무 with 파이썬 사용파일/스타벅스/seoul_sgg.geojson'
seoul_sgg_geo_2 = json.load(open(sgg_geojson_file_path, encoding='utf-8'))

# %%
#  서울시 시군구별 주민등록인구수 단계구분도 지도 시각화
starbucks_choropleth = folium.Map(
    location=[37.573050, 126.979189],
    tiles='CartoDB dark_matter',
    zoom_start=11
)

folium.Choropleth(
    geo_data=seoul_sgg_geo_2,
    data=seoul_sgg_stat,
    columns=['시군구명', '주민등록인구'],
    fill_color = 'YlGn',
    fill_opacity=0.7,
    line_opacity=0.5,
    key_on='properties.SIG_KOR_NM'
    ).add_to(starbucks_choropleth)

starbucks_choropleth

# %%
# 인구 만 명당 스타벅스 매장 수 칼럼 추가
seoul_sgg_stat['만명당_매장수'] = seoul_sgg_stat['사업체수']/(seoul_sgg_stat['주민등록인구']/10000)

# %%
# 예제 6-70  인구 만 명당 스타벅스 매장 수 지도 시각화
SGG_GEOJSON_FILE_PATH = '/content/drive/MyDrive/코딩 공부/colab/colab사용 파일/직장인을 위한 데이터 분석 실무 with 파이썬 사용파일/스타벅스/seoul_sgg.geojson'
seoul_sgg_geo_1 = json.load(open(SGG_GEOJSON_FILE_PATH, encoding='utf-8'))

viz_map_1 = folium.Map(
    location=[37.573050, 126.979189],
    tiles='CartoDB dark_matter',
    zoom_start=11
)

# 지도 스타일 지정 함수
def style_function(feature):
    return {
        'opacity': 0.7,
        'weight': 1,
        'fillOpacity':0,
    }

folium.GeoJson(
    seoul_sgg_geo_2,
    style_function=style_function,
).add_to(viz_map_1)
# 만명당 매장수 기준 상위 10% 추출 값
top = seoul_sgg_stat ['만명당_매장수'].quantile(0.9)
for idx in seoul_sgg_stat.index:
    lat = seoul_sgg_stat.loc[idx, '위도']
    lng = seoul_sgg_stat.loc[idx, '경도']
    r = seoul_sgg_stat.loc[idx, '만명당_매장수']
    if r > top:
        fillColor = '#FF3300' # (Red)
    else:
        fillColor = '#CCFF33' # (Green)
    
    folium.CircleMarker(
        location=[lat, lng], 
        color='#FFFF00',     # (Yellow)
        fill_color=fillColor, 
        fill_opacity=0.7,
        weight=1.5,
        radius= r * 10
    ).add_to(viz_map_1)

viz_map_1

# %% [markdown]
# ###스타벅스 매장 수와 사업체 수 비교

# %%
#  신규 칼럼을 생성해 값 입력
seoul_sgg_stat['종사자수_만명당_매장수'] = seoul_sgg_stat['사업체수']/(seoul_sgg_stat['종사자수']/10000)
seoul_sgg_stat.head()

# %%
#  종사자 수 1만 명당 스타벅스 매장 수 시각화
seoul_sgg_geo_1 = json.load(open(SGG_GEOJSON_FILE_PATH, encoding='utf-8'))

viz_map_1 = folium.Map(
    location=[37.573050, 126.979189],
    tiles='CartoDB dark_matter',
    zoom_start=11
)

folium.GeoJson(
    seoul_sgg_geo_1,
    style_function=style_function,
).add_to(viz_map_1)

top = seoul_sgg_stat['종사자수_만명당_매장수'].quantile(0.9)
for idx in seoul_sgg_stat.index:
    name = seoul_sgg_stat.at[idx, '시군구명']
    lat = seoul_sgg_stat.loc[idx, '위도']
    lng = seoul_sgg_stat.loc[idx, '경도']
    r = seoul_sgg_stat.loc[idx, '종사자수_만명당_매장수']
    
    if r > top:
        fillColor = '#FF3300'
    else:
        fillColor = '#CCFF33'
    
    folium.CircleMarker(
        location=[lat, lng], 
        color='#FFFF00', 
        fill_color=fillColor, 
        fill_opacity=0.7,
        weight=1.5,
        radius= r * 10
    ).add_to(viz_map_1)

viz_map_1

# %% [markdown]
# # 어떤 무선청소기가 인기가 좋을까?

# %% [markdown]
# ## 데이터 수집 1 – 한 페이지 크롤링

# %% [markdown]
# ###다나와 검색 페이지 접속

# %%
#elenium으로 다나와 검색 결과 URL에 접속
from selenium import webdriver

url = "http://search.danawa.com/dsearch.php?query=블루투스+이어폰&tab=main"
driver.get(url)

# %% [markdown]
# ###다나와 검색 웹 페이지에서 상품 정보 가져오기

# %%
from bs4 import BeautifulSoup

#  웹 페이지의 HTML 정보 가져오기
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
#  1페이지에 대한 무선청소기 정보 가져오기 1
prod_items = soup.select('li.prod_item')
len(prod_items)
# Out:
# 46

# %%
# 1페이지에 대한 무선청소기 정보 가져오기 2
prod_items = soup.select('ul.product_list > li.prod_item')
len(prod_items)
# Out:
# 46

# %%
# 1페이지에 대한 무선청소기 정보 가져오기 3
prod_items = soup.select('div.main_prodlist > ul.product_list > li.prod_item')
len(prod_items)
# Out:
# 44

# %%
# 상품명 정보 가져오기
title = prod_items[0].select('p.prod_name > a')[0].text.strip()
print(title)
# Out:
# 삼성전자 갤럭시 버즈2 프로 SM-R510

# %%
# 스펙 목록 정보 가져오기
spec_list = prod_items[0].select('div.spec_list')[0].text.replace('\t','').replace('\n','')  # 수정버전(2022.05.19)
print(spec_list)
# Out:
# 이어폰 / 무선 / 코드리스 / 커널형 / 블루투스 v5.0 / HFP / HSP / AVRCP / A2DP / 오토페어링 / 핸즈프리통화 / 전용어플 / 터치버튼 / 재생/멈춤조절 / 재생시간: 최대 5시간 / 대기시간: 150시간 / 충전시간: 1.5시간 / 배터리용량: 40mAh / 무게: 4.2g / 케이스배터리용량: 300mAh

# %%
# 가격 정보 가져오기
price = prod_items[0].select('li.rank_one > p.price_sect > a > strong')[0].text.strip().replace(",","")
print(price)
# Out:
# 187210

# %%
#반복문으로 검색 결과의 1페이지에 대한 상품 정보 추출
prod_data = []
for prod_item in prod_items:
    if 'product-pot' in prod_item['class']:
        continue  # 공백부분(‘li.prod_item.product-pot’) 제외하기
    try:
        # ① 상품명 가져오기
        title = prod_item.select('p.prod_name > a')[0].text.strip()
        # ② 스펙 목록 가져오기
        spec_list = prod_items[0].select('div.spec_list')[0].text.replace('\t','').replace('\n','')  # 수정버전(2022.05.19)
        # ③ 가격 정보 가져오기 
        price = prod_item.select('li.rank_one > p.price_sect > a > strong')[0].text.strip().replace(",", "")
        
        prod_data.append([title, spec_list, price])
    except:
        pass  # 진행시 에러가 발생할 경우(광고 상품 등) 넘어가기
print(len(prod_data))
print(prod_data)
# Out:
# 40
# ...

# %%
#상품 정보 태그에서 원하는 정보를 추출하는 함수
def get_prod_items(prod_items):
    prod_data = []
    for prod_item in prod_items:
        if 'product-pot' in prod_item['class']:
            continue  # 공백부분(‘li.prod_item.product-pot’) 제외하기
        try:
            # ① 상품명 가져오기
            title = prod_item.select('p.prod_name > a')[0].text.strip()
            # ② 스펙 목록 가져오기
            spec_list = prod_items[0].select('div.spec_list')[0].text.replace('\t','').replace('\n','')  # 수정버전(2022.05.19)
            # ③ 가격 정보 가져오기
            price = prod_item.select('li.rank_one > p.price_sect > a > strong')[0].text.strip().replace(",", "")
            prod_data.append([title, spec_list, price])
        except:
            pass  # 진행시 에러가 발생할 경우(광고 상품 등) 넘어가기
    return prod_data

# %%
# 상품 정보를 가져오는 함수 테스트
prod_items = soup.select('div.main_prodlist > ul.product_list > li.prod_item')
prod_data = get_prod_items(prod_items)
print(len(prod_data))
# Out:
# 40

# %% [markdown]
# ##데이터 수집 2 - 여러 페이지에 걸친 다나와 검색 페이지 크롤링

# %% [markdown]
# ### 다나와 검색 결과 페이지 URL 분석

# %%
# 다나와 검색 URL을 만들어주는 함수 
def get_search_page_url(keyword, page):
    return 'http://search.danawa.com/dsearch.php?query={}&volumeType=allvs&page={}&limit=30&sort=saveDESC&list=list&boost=true&addDelivery=N&tab=goods&tab=goods'.format(keyword, page)

keyword = '블루투스+이이폰'
page = 1
url = get_search_page_url(keyword, page)
print(url)
# Out:
# http://search.danawa.com/dsearch.php?query=블루투스+이이폰&volumeType=allvs&page=1&limit=30&sort=saveDESC&list=list&boost=true&addDelivery=N&tab=goods&tab=goods

# %% [markdown]
# ###주피터 노트북의 진행표시줄 처리

# %%
# tqdm 라이브러리 설치 
! pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# tqdm 사용법 
import time
from tqdm.notebook import tqdm  # tqdm 라이브러리 명령어 변경에 따른 코드 변경(2022.10.03)
total_page = 10
for page in tqdm(range(1, total_page + 1)):
    # 페이지가 로딩 완료되기 위한 시간을 5초로 준다. 
    time.sleep(5)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ###여러 페이지에 걸친 상품 정보 수집

# %%
# 실전 다나와 크롤링
from selenium import webdriver
import time
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm  # tqdm 라이브러리 명령어 변경에 따른 코드 변경(2022.10.03)

# driver = webdriver.Chrome('c:/playwithdata/chromedriver.exe')
# # 암묵적으로 웹 자원 로드를 위해 3초까지 기다림
# driver.implicitly_wait(3)

keyword = '블루투스+이어폰'
total_page = 10
prod_data_total = []
# 진행 정도를 표현하는 tqdm을 적용 
for page in tqdm(range(1, total_page + 1)):
    # ① 검색 페이지 이동
    url = get_search_page_url(keyword, page)
    driver.get(url)
    # 페이지가 로딩 완료되기 위한 시간으로 5초를 할당
    time.sleep(5)
    
    # ② 현재 페이지의 HTML 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # ③ 상품 정보 추출
    prod_items = soup.select('div#productListArea > div.main_prodlist > ul.product_list > li.prod_item')
    prod_item_list = get_prod_items(prod_items)
    
    # ④ 추출 데이터 저장
    prod_data_total = prod_data_total + prod_item_list
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ###수집 데이터 저장

# %%
# 데이터 저장
import pandas as pd
data = pd.DataFrame(prod_data_total)
data.columns = ['상품명', '스펙 목록', '가격']
data.to_excel('./1_danawa_crawling_result.xlsx', index = False)

# %% [markdown]
# ## 다나와 크롤링 데이터 전처리

# %% [markdown]
# ###다나와 크롤링 데이터 불러오기

# %%
# 다나와 크롤링 결과 가져오기 
import pandas as pd

data = pd.read_excel('./1_danawa_crawling_result.xlsx')
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   상품명     400 non-null    object
#  1   스펙 목록   400 non-null    object
#  2   가격      400 non-null    object
# dtypes: object(3)
# memory usage: 9.5+ KB
#                              상품명  \
# 0        삼성전자 갤럭시 버즈2 프로 SM-R510
# 1     APPLE 에어팟 프로 2세대 MQD83KH/A
# 2  APPLE 에어팟 프로 2021년형 MLWK3KH/A
# 3                        QCY T13
# 4           삼성전자 갤럭시 버즈2 SM-R177
#
#                                                스펙 목록      가격
# 0  이어폰 / 무선 / 스마트폰공용 / 코드리스 / 커널형 / 블루투스 v5.3 / S...  187210
# 1  이어폰 / 무선 / 스마트폰공용 / 코드리스 / 커널형 / 블루투스 v5.3 / S...  326400
# 2  이어폰 / 무선 / 스마트폰공용 / 코드리스 / 커널형 / 블루투스 v5.3 / S...  241080
# 3  이어폰 / 무선 / 스마트폰공용 / 코드리스 / 커널형 / 블루투스 v5.3 / S...   20630
# 4  이어폰 / 무선 / 스마트폰공용 / 코드리스 / 커널형 / 블루투스 v5.3 / S...   86950

# %% [markdown]
# ###회사명, 모델명 정리

# %%
# 회사명 + 모델명 분리
company_list = []
product_list = []
for title in data['상품명']:
    title_info = title.split(' ', 1)
    company_name = title_info[0]
    product_name = title_info[1]
    company_list.append(company_name)
    product_list.append(product_name)

# %% [markdown]
# ###스펙 목록에서 카테고리, 사용시간, 흡입력을 추출해서 정리

# %%
#  첫 번째 제품의 스펙 목록 분리
spec_list = data['스펙 목록'][1].split(' / ')
spec_list
# Out:
# ['이어폰',
#  '무선',
#  '스마트폰공용',
#  '코드리스',
#  '커널형',
#  '블루투스 v5.3',
#  'SBC',
#  'AAC',
#  'HFP',
#  'AVRCP',
#  'A2DP',
#  '멀티페어링',
#  '액티브노이즈캔슬링',
#  '주변소리듣기',
#  '오토페어링',
#  '핸즈프리통화',
#  '좌우개별통화',
#  '퀵충전',
#  '전용어플',
#  '터치버튼',
#  '재생/멈춤조절',
#  '볼륨조절',
#  'IPX7방수',
#  '재생시간: 5시간(ANC ON), 8시간(ANC OFF)',
#  '충전케이스 포함 최대: 18시간(ANC ON), 29시간(ANC OFF)',
#  '통화시간: 3.5시간(ANC ON), 4시간(ANC OFF)',
#  '배터리용량: 61mAh',
#  '충전단자: USB타입C, 무선충전',
#  '무게: 5.5g',
#  '케이스배터리용량: 515mAh',
#  '케이스무게: 43.4g',
#  '24bit Hi-Fi 사운드',
#  '360오디오',
#  'High-SNR 마이크 3개',
#  '이어폰 찾기 기능',
#  '삼성전자 스마트TV와 오토스위칭',
#  '출시가: 279,000원']

# %%
# 카테고리 정보 추출
category = spec_list[0] 
category
# Out:
# '이어폰'

# %%
# ‘사용시간’, ‘흡입력’이 포함된 원소 추출 
for spec in spec_list:
    if '배터리용량' in spec: 
         use_time_spec = spec 
    elif '출시가' in spec:
        release_price_spec = spec 
    elif '무게' in spec:
        weight_spec = spec  
print(use_time_spec)
print(release_price_spec)
print(weight_spec)
# Out:
# 케이스배터리용량: 515mAh
# 출시가: 279,000원
# 케이스무게: 43.4g

# %%
# 예제 7-22 정량적인 수치 추출 
import re
use_time_value=re.sub(r'[^0-9]', '',use_time_spec)
suction_value=re.sub(r'[^0-9]', '',release_price_spec)
weight_value=re.sub(r'[^0-9^.]', '',weight_spec)
# use_time = use_time_spec.split(' ')[1].strip() 
# suction_value = release_price_spec.split(' ')[1].strip()

print(use_time_value)
print(suction_value)
print(weight_value)
# Out:
# 515
# 279000
# 43.4

# %%
# 예제 7-23 카테고리, 사용시간, 흡입력 추출 
category_list = []
use_time_list = []
suction_list = [] 
weight_list = []
for spec_data in data['스펙 목록']:
    # ' / ' 기준으로 스펙 분리하기 
    spec_list = spec_data.split(' / ')
    
    # 카테고리 추출하기
    category = spec_list[0] 
    category_list.append(category)
    
    # 사용시간, 흡입력 추출 
    ## 사용시간, 흡입력 정보가 없는 제품을 위해 변수를 생성 
    use_time_value = None 
    suction_value = None 
    weight_value = None
    
    ## spec_list의 각 원소에서 사용시간, 흡입력 수치 추출
    for spec in spec_list:
        if '배터리용량' in spec: 
            use_time_value =re.sub(r'[^0-9]', '',use_time_spec)       
        if '출시가' in spec:
            suction_value =re.sub(r'[^0-9]', '',release_price_spec)
        if '무게' in spec:
            weight_value =re.sub(r'[^0-9^.]', '',weight_spec)
    use_time_list.append(use_time_value)
    suction_list.append(suction_value)
    weight_list.append(weight_value)

# %% [markdown]
# ###사용시간 단위 통일시키기

# %%
# 사용시간을 분 단위로 조정하는 함수
def convert_time_minute(time):
    try:
        if '시간' in time:
            hour = time.split('시간')[0]
            if '분' in time:
                minute = time.split('시간')[-1].split('분')[0]
            else:
                minute = 0
        else: 
            hour = 0
            minute = time.split('분')[0]
        return int(hour)*60 + int(minute)
    except:
        return None

# %%
# 사용시간을 분 단위로 조정하는 함수의 테스트
times = ["40분", "4분", "1시간", "3시간30분", "4시간"]
for time in times:
    time_value = convert_time_minute(time)
    print(time, "=", time_value)
# Out:
# 40분 = 40
# 4분 = 4
# 1시간 = 60
# 3시간30분 = 210
# 4시간 = 240

# %% [markdown]
# ### 무선 청소기 흡입력 단위 통일시키기

# %% [markdown]
# ###다나와 전처리 결과를 엑셀로 저장

# %%
#  전처리 데이터 확인
pd_data = pd.DataFrame()
pd_data['카테고리'] = category_list
pd_data['회사명'] = company_list
pd_data['제품'] = product_list
pd_data['가격'] = data['가격']
pd_data['배터리용량'] = use_time_value
pd_data['출시가'] = suction_list
pd_data.head()
# Out:
#   카테고리    회사명                       제품      가격 배터리용량     출시가
# 0  이어폰   삼성전자       갤럭시 버즈2 프로 SM-R510  187210   515  279000
# 1  이어폰  APPLE     에어팟 프로 2세대 MQD83KH/A  326400   515  279000
# 2  이어폰  APPLE  에어팟 프로 2021년형 MLWK3KH/A  244010   515  279000
# 3  이어폰    QCY                      T13   20640   515  279000
# 4  이어폰   삼성전자          갤럭시 버즈2 SM-R177   87920   515  279000

# %%
# 카테고리 분류 기준 및 데이터 개수 점검
pd_data['카테고리'].value_counts()
# Out:
# 이어폰    360
# 모노셋     40
# Name: 카테고리, dtype: int64

# %%
#핸디/스틱청소기만 선택
pd_data_final = pd_data[pd_data['카테고리'].isin(['이어폰'])]
len(pd_data_final)
# Out:
# 360

# %%
#가격 데이터 살펴보기
pd_data_final['가격'].unique()   # 이상값 확인  "가격비교예정" 제외 필요
# Out:
# array(['187210', '326400', '244010', '20640', '87920', '215100', '18200',
#        '219950', '72250', '23360', '120318', '138900', '253000', '359000',
#        '109900', '27510', '166150', '157170', '75900', '39190', '109000',
#        '34400', '14760', '29060', '119540', '78062', '49410', '32900',
#        '19890', '71110', '19900', '241530', '135590', '73870', '21000',
#        '87190', '77000', '126650', '356560', '84550', '18900', '94670',
#        '59800', '268990', '139000', '168300', '34100', '43553', '11870',
#        '47820', '67000', '47230', '47990', '32930', '59000', '67410',
#        '29900', '86000', '58103', '29003', '22090', '44523', '39600',
#        '159000', '45070', '29890', '54900', '88990', '69000', '14900',
#        '35793', '79000', '39900', '11150', '89000', '84900', '91080',
#        '35520', '28700', '59530', '19500', '108880', '79900', '88070',
#        '36100', '70960', '49900', '11710', '17780', '129890', '19800',
# ...

# %%
# "가격비교예정"  상품 제외하기 2022.05.19
cond = pd_data_final['가격'] != '가격비교예정'
pd_data_final = pd_data_final[cond]
pd_data_final
# Out:
#     카테고리    회사명                       제품      가격 배터리용량     출시가
# 0    이어폰   삼성전자       갤럭시 버즈2 프로 SM-R510  187210   515  279000
# 1    이어폰  APPLE     에어팟 프로 2세대 MQD83KH/A  326400   515  279000
# 2    이어폰  APPLE  에어팟 프로 2021년형 MLWK3KH/A  244010   515  279000
# 3    이어폰    QCY                      T13   20640   515  279000
# 4    이어폰   삼성전자          갤럭시 버즈2 SM-R177   87920   515  279000
# ..   ...    ...                      ...     ...   ...     ...
# 395  이어폰    샤오미       레드미 버즈4 프로 M2132E1   77444   515    None
# 396  이어폰  Britz    브리츠인터내셔널 AcousticTWS7   61900   515    None
# 397  이어폰    자브라              엘리트 액티브 75t   79890   515    None
# 398  이어폰    NEW                  BEE M50   37900   515    None
# 399  이어폰     코시            젬스톤 EP2030BTW   34190   515    None
#
# [359 rows x 6 columns]

# %%
# 엑셀로 저장
pd_data_final.to_excel('./2_danawa_data_final.xlsx', index = False)

# %% [markdown]
# ##무선청소기 모델별 비교 분석

# %% [markdown]
# ###데이터 살펴보기

# %%
# 데이터 불러오기 
import pandas as pd
danawa_data = pd.read_excel('./2_danawa_data_final.xlsx')
danawa_data.head()
# Out:
#   카테고리    회사명                       제품      가격  배터리용량       출시가
# 0  이어폰   삼성전자       갤럭시 버즈2 프로 SM-R510  187210    515  279000.0
# 1  이어폰  APPLE     에어팟 프로 2세대 MQD83KH/A  326400    515  279000.0
# 2  이어폰  APPLE  에어팟 프로 2021년형 MLWK3KH/A  244010    515  279000.0
# 3  이어폰    QCY                      T13   20640    515  279000.0
# 4  이어폰   삼성전자          갤럭시 버즈2 SM-R177   87920    515  279000.0

# %%
# 출시가 기준 정렬
top_list = danawa_data.sort_values(["출시가"], ascending = False)
top_list.head()
# Out:
#    카테고리    회사명                    제품      가격  배터리용량       출시가
# 0   이어폰   삼성전자    갤럭시 버즈2 프로 SM-R510  187210    515  279000.0
# 1   이어폰  APPLE  에어팟 프로 2세대 MQD83KH/A  326400    515  279000.0
# 22  이어폰    QCY                   T17   14760    515  279000.0
# 23  이어폰    QCY                   T18   29060    515  279000.0
# 24  이어폰   삼성전자     갤럭시 버즈 프로 SM-R190  119540    515  279000.0

# %%
# 가격 기준 정렬
top_list = danawa_data.sort_values(["가격"], ascending = False)
top_list.head()
# Out:
#     카테고리    회사명                                 제품       가격  배터리용량       출시가
# 205  이어폰     슈어                              SE846  1329000    515       NaN
# 247  이어폰    AKG                              N5005   473000    515       NaN
# 175  이어폰  APPLE  Beats by Dr.Dre 파워비츠 프로 MV6Y2ZP/A   362040    515       NaN
# 13   이어폰   BOSE                      QC Earbuds II   359000    515  279000.0
# 38   이어폰  뱅앤올룹슨                         Beoplay EQ   356560    515  279000.0

# %%
#  배터리용량, 출시가 기준으로 정렬
top_list = danawa_data.sort_values(["배터리용량","출시가"], ascending = False)
top_list.head()
# Out:
#   카테고리    회사명                       제품      가격  배터리용량       출시가
# 0  이어폰   삼성전자       갤럭시 버즈2 프로 SM-R510  187210    515  279000.0
# 1  이어폰  APPLE     에어팟 프로 2세대 MQD83KH/A  326400    515  279000.0
# 2  이어폰  APPLE  에어팟 프로 2021년형 MLWK3KH/A  244010    515  279000.0
# 3  이어폰    QCY                      T13   20640    515  279000.0
# 4  이어폰   삼성전자          갤럭시 버즈2 SM-R177   87920    515  279000.0

# %%
# 평균값 정리
price_mean_value = danawa_data['가격'].mean()
suction_mean_value = danawa_data['출시가'].mean()
use_time_mean_value = danawa_data['배터리용량'].mean()
print("가격 평균값", price_mean_value)
print("출시가 평균값", suction_mean_value)
print("배터리 용량 평균값", use_time_mean_value)
# Out:
# 가격 평균값 81178.12534818941
# 출시가 평균값 279000.0
# 배터리 용량 평균값 515.0

# %%
# 가성비 좋은 제품 탐색
condition_data = danawa_data [
    (danawa_data['가격'] <= price_mean_value) & 
    (danawa_data['출시가'] >= suction_mean_value) & 
    (danawa_data['배터리용량'] >= use_time_mean_value)]
condition_data
# Out:
#    카테고리    회사명                  제품     가격  배터리용량       출시가
# 3   이어폰    QCY                 T13  20640    515  279000.0
# 6   이어폰    QCY   MeloBuds ANC HT05  18200    515  279000.0
# 8   이어폰   삼성전자  갤럭시 버즈 라이브 SM-R180  72250    515  279000.0
# 9   이어폰    QCY        AilyPods T20  23360    515  279000.0
# 15  이어폰    QCY       FairyBuds T21  27510    515  279000.0
# 18  이어폰   LG전자       Tone+ HBS-PL5  75900    515  279000.0
# 19  이어폰    JBL         WAVE 100TWS  39190    515  279000.0
# 21  이어폰  Britz   브리츠인터내셔널 BE-ME600  34400    515  279000.0
# 22  이어폰    QCY                 T17  14760    515  279000.0
# 23  이어폰    QCY                 T18  29060    515  279000.0
# 25  이어폰    JBL          TUNE 230NC  78062    515  279000.0
# 26  이어폰  Britz   브리츠인터내셔널 BE-BONE7  49410    515  279000.0
# 27  이어폰  Britz  브리츠인터내셔널 StormTWS7  32900    515  279000.0
# 28  이어폰     앱코       BEATONIC EF01  19890    515  279000.0
# 29  이어폰  Britz   브리츠인터내셔널 BE-BONE9  71110    515  279000.0
# ...

# %% [markdown]
# ###데이터 시각화

# %%
# 예제 7-40 라이브러리 임포트 및 한글 글꼴 설정
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import seaborn as sns
import platform

# %%
font_path = '/content/drive/MyDrive/코딩 공부/colab/colab사용 파일/폰트/Gugi-Regular.ttf'
rc('font', family = 'Gugi-Regular')

# %%
# %matplotlib inline

# %%
#결측값 없애기
chart_data = danawa_data.dropna(axis = 0)
len(chart_data)
# Out:
# 40

# %%
# 가격, 출시가의 최댓값/최솟값 정리
# 가격, 출시가 최대, 최소
suction_max_value = chart_data['가격'].max()
suction_mean_value = chart_data['가격'].mean()
use_time_max_value = chart_data['출시가'].max()
use_time_mean_value = chart_data['출시가'].mean()

# %%
# 청소기 성능 시각화
plt.figure(figsize=(20, 10))
plt.title("블루투스 이어폰 차트")
sns.scatterplot(x = '출시가', y = '배터리용량', size = '가격', hue = chart_data['회사명'], 
             data = chart_data, sizes = (300000, 140000), legend = False)
plt.plot([0, suction_max_value], 
          [use_time_mean_value, use_time_mean_value], 
          'r--', 
          lw = 1 )
plt.plot([suction_mean_value, suction_mean_value], 
          [0, use_time_max_value], 
          'r--', 
          lw = 1 )
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48660 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47336 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 53804 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
