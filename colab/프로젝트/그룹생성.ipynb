# %%
import random

def make_groups(member_list, group_size):
    random.shuffle(member_list)  # 그룹을 만들기 전에 리스트를 무작위로 섞음
    num_members = len(member_list)
    num_groups = -(-num_members // group_size)  # 올림을 이용하여 총 그룹 수를 계산

    groups = []
    for i in range(num_groups):
        start_idx = i * group_size
        end_idx = (i + 1) * group_size
        groups.append(member_list[start_idx:end_idx])

    return groups

def main():
    group = ["김나홍","어울림","마지원","이태영","이지연","김채운","조준서","유태양","이신희","강혁주","안석규","정세아","홍은경","노시현","이윤자","이산하","박해솔","배승아","김상열","배성원","안보록","현서윤","이주영","조민성","이상연","김민재","김주왕","정승혜","오민정","권나현","윤수민","이주윤","양민주","이지은","이연주","장선민","이승준","오욱진","정시윤","이진우","성민준","정예은","윤준서","신주연","장한이","정윤지","노현아","여동원","김은성","오태경","이다윤","신영원","이아린","현명빈","김현우","홍지환","장호진","이주현"]
    group_size = int(input("한 그룹 당 몇 명의 인원을 원하시나요? "))
    groups = make_groups(group, group_size)

    for i, group_members in enumerate(groups):
        print(f"group{i+1}={group_members}")

if __name__ == "__main__":
    main()
# Out:
# 한 그룹 당 몇 명의 인원을 원하시나요? 4
# group1=['정예은', '현서윤', '여동원', '김상열']
# group2=['김나홍', '성민준', '윤준서', '정세아']
# group3=['홍지환', '배승아', '홍은경', '장한이']
# group4=['조민성', '김주왕', '권나현', '안보록']
# group5=['이주영', '유태양', '김채운', '장선민']
# group6=['이산하', '김은성', '조준서', '이승준']
# group7=['이주현', '윤수민', '이다윤', '이주윤']
# group8=['이진우', '이지연', '장호진', '정시윤']
# group9=['강혁주', '이연주', '이신희', '오욱진']
# group10=['마지원', '오태경', '정승혜', '정윤지']
# group11=['이상연', '노현아', '박해솔', '노시현']
# group12=['신영원', '김현우', '배성원', '신주연']
# group13=['이아린', '어울림', '김민재', '이윤자']
# group14=['이지은', '오민정', '현명빈', '안석규']
# group15=['양민주', '이태영']
